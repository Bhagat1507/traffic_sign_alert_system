# %%
import numpy as np
import cv2

# %%
import uuid
import os
import time

# %%
IMAGES_PATH = os.path.join('train_data1', 'images','train') #/data/images
IMAGES_PATH1= os.path.join("train_data1",'images','val')
labels = ['zebra crossing']
number_imgs=100
number_imgs1 = 10

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(1)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

for label in labels:
    print('Collecting images for {}'.format(label))
    
    # Loop through image range
    for img_num in range(number_imgs1):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH1, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
# 'parking','no-parking','stop','give-a-way','men-at-work',
#          'zebra-crossing','speed-limit-25','no-left-turn','no-right-turn',
#          '2-way-traffic','max-speed-40','u-turn','no-u-turn',
#          'slope','railroad','no-overtaking','horn-prohibited',
#          'bicycle-crossing','red-light','yellow-light','green-light',
#          't-junction','narrow-bridge'

# %%
# Out:
# C:\Users\amals\AppData\Local\Programs\Python\Python39\Scripts\pyrcc5: File does not exist 'resources.qrc'

# %%
# !git clone https://github.com/tzutalin/labelImg
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.
# ...

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14108/3436357687.py in <module>
#       1 i=0
# ----> 2 for j in names:
#       3     i+=1
#       4 print(i)
#
# NameError: name 'names' is not defined
